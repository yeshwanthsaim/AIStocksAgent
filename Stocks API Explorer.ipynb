# %% [raw]
# Aim: To get aqcuinted with the free APIs avaliable for stock data
# List :
#     NSE - nsetools
#     Alphavantage

# %%
# importing nse from nse tools
from nsetools import Nse

# creating a Nse object
nse = Nse()

# printing Nse object
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
import nsetools

# %%
nsetools.__file__
# Out:
# 'C:\\Users\\yeshu\\.conda\\envs\\ai\\lib\\site-packages\\nsetools\\__init__.py'

# %%
q = nse.get_quote('infy')
# Out:
# time diff is  12

# %%
#### Summary::> NSE library has issues with latest updates

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='KIC1EWE0NFRH4Z8N')

# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('GOOGL')

# %%
data
# Out:
# {'2024-11-01 19:45:00': {'1. open': '170.9800',
#   '2. high': '171.0900',
#   '3. low': '170.8500',
#   '4. close': '171.0800',
#   '5. volume': '2874'},
#  '2024-11-01 19:30:00': {'1. open': '171.0100',
#   '2. high': '171.0900',
#   '3. low': '170.8500',
#   '4. close': '170.8500',
#   '5. volume': '1473'},
#  '2024-11-01 19:15:00': {'1. open': '171.0000',
#   '2. high': '171.0900',
#   '3. low': '171.0000',
#   '4. close': '171.0400',
#   '5. volume': '842'},
#  '2024-11-01 19:00:00': {'1. open': '170.9800',
#   '2. high': '171.1000',
#   '3. low': '170.8500',
#   '4. close': '171.0100',
#   '5. volume': '992'},
#  '2024-11-01 18:45:00': {'1. open': '171.1000',
#   '2. high': '171.1100',
#   '3. low': '170.8500',
#   '4. close': '170.9900',
#   '5. volume': '6600'},
#  '2024-11-01 18:30:00': {'1. open': '171.0800',
#   '2. high': '171.1500',
#   '3. low': '171.0000',
#   '4. close': '171.1100',
#   '5. volume': '5359'},
#  '2024-11-01 18:15:00': {'1. open': '171.0400',
# ...

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TOP_GAINERS_LOSERS&apikey=KIC1EWE0NFRH4Z8N'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'metadata': 'Top gainers, losers, and most actively traded US tickers', 'last_updated': '2024-11-01 16:15:59 US/Eastern', 'top_gainers': [{'ticker': 'ONYXW', 'price': '0.0025', 'change_amount': '0.0015', 'change_percentage': '150.0%', 'volume': '751'}, {'ticker': 'VSTE', 'price': '4.8', 'change_amount': '2.8', 'change_percentage': '140.0%', 'volume': '67395501'}, {'ticker': 'SVREW', 'price': '0.023', 'change_amount': '0.0127', 'change_percentage': '123.301%', 'volume': '12018'}, {'ticker': 'SRZNW', 'price': '0.02', 'change_amount': '0.0106', 'change_percentage': '112.766%', 'volume': '25781'}, {'ticker': 'DATSW', 'price': '0.06', 'change_amount': '0.0295', 'change_percentage': '96.7213%', 'volume': '100'}, {'ticker': 'VSTEW', 'price': '0.1112', 'change_amount': '0.0518', 'change_percentage': '87.2054%', 'volume': '2010590'}, {'ticker': 'NIVFW', 'price': '0.0347', 'change_amount': '0.0147', 'change_percentage': '73.5%', 'volume': '1359'}, {'ticker': 'SWAGW', 'price': '0.0173', 'chang
# ...

# %%
data.keys()
# Out:
# dict_keys(['metadata', 'last_updated', 'top_gainers', 'top_losers', 'most_actively_traded'])

# %%
import pandas as pd
df = pd.DataFrame(data['top_gainers'])

# %%
df
# Out:
#    ticker   price change_amount change_percentage    volume
# 0   ONYXW  0.0025        0.0015            150.0%       751
# 1    VSTE     4.8           2.8            140.0%  67395501
# 2   SVREW   0.023        0.0127          123.301%     12018
# 3   SRZNW    0.02        0.0106          112.766%     25781
# 4   DATSW    0.06        0.0295          96.7213%       100
# 5   VSTEW  0.1112        0.0518          87.2054%   2010590
# 6   NIVFW  0.0347        0.0147             73.5%      1359
# 7   SWAGW  0.0173         0.007          67.9612%      7635
# 8    CDXC    5.86          2.37          67.9083%  37413862
# 9    TDW+  0.0583        0.0234          67.0487%      1283
# 10  COCHW  0.0966        0.0372          62.6263%     34978
# 11  TCBPW    0.02        0.0075             60.0%     72890
# 12  SABSW    0.08          0.03             60.0%     73677
# 13  RVMDW     0.3           0.1             50.0%    249770
# 14  ABVEW  0.0294        0.0096          48.4848%     92794
# ...

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

company_name = msft.info['longName']

# %%
def getName(t):
    try:
        t = t.replace("+","")
        company = yf.Ticker(t)
        company_name = company.info['longName']
        return company_name
    except:
        return "Unknow"

# %%
df['Company Name'] = df.ticker.apply(getName)

# %%
df
# Out:
#    ticker   price change_amount change_percentage    volume  \
# 0   ONYXW  0.0025        0.0015            150.0%       751
# 1    VSTE     4.8           2.8            140.0%  67395501
# 2   SVREW   0.023        0.0127          123.301%     12018
# 3   SRZNW    0.02        0.0106          112.766%     25781
# 4   DATSW    0.06        0.0295          96.7213%       100
# 5   VSTEW  0.1112        0.0518          87.2054%   2010590
# 6   NIVFW  0.0347        0.0147             73.5%      1359
# 7   SWAGW  0.0173         0.007          67.9612%      7635
# 8    CDXC    5.86          2.37          67.9083%  37413862
# 9    TDW+  0.0583        0.0234          67.0487%      1283
# 10  COCHW  0.0966        0.0372          62.6263%     34978
# 11  TCBPW    0.02        0.0075             60.0%     72890
# 12  SABSW    0.08          0.03             60.0%     73677
# 13  RVMDW     0.3           0.1             50.0%    249770
# 14  ABVEW  0.0294        0.0096          48.4848%     92794
# ...

# %%
list(df['Company Name'][:3].values)
# Out:
# ['Onyx Acquisition Co. I', 'Vast Renewables Limited', 'SaverOne 2014 Ltd.']
